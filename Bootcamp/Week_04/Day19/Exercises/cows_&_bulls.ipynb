# %% [markdown]
# - [Cows_and_Bulls]
#
# Say the number generated by the computer is 1038. An example interaction could look like this:
#
#   Welcome to the Cows and Bulls Game!
#
#   >Enter a number:
#
#   >> 1234
#
#   >>> 2 cows, 0 bulls
#
#   >> 1253
#
#   >>> 1 cow, 1 bull
#
#   ...
# Until the user guesses the number or write "STOP"

# %%
number_to_guess = input("Enter a four-digit number or STOP to stop the game")
number_to_compare = input("Enter a four-digit number or STOP to stop the game")
cows = 0
bulls = 0

while True:
    if len(number_to_guess) != 4:
        number_to_guess = input("Please, enter a four-digit number:")
    elif number_to_guess == "STOP":
        break
    elif cows == 4:
        print("You win")
        break
    if len(number_to_guess) == 4:
        while cows < 4:
            if len(number_to_compare) != 4:
                number_to_compare = input("Please, enter a four-digit number:")
            elif number_to_compare == "STOP":
                break
            elif len(number_to_compare) == 4:
                for x in range(0,4):
                    if number_to_compare[x] == number_to_guess[x]:
                        cows += 1
                    
                    else:
                        for i in number_to_compare:
                            for y in number_to_guess:
                                if i == y:
                                    bulls += 1
                                else:
                                    bulls = bulls

print("Cows", str(cow), "and", "Bulls", str(bull))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c8a675f04dd2> in <module>
#       3
#       4 while True:
# ----> 5     cow = 0
#       6     bull = 0
#       7     if len(number_to_guess) == 4:
#
# KeyboardInterrupt:

# %%
number_to_guess = input("Enter a four-digit number or STOP to stop the game")
number_to_compare = input("Enter a four-digit number or STOP to stop the game")
cows = 0
bulls = 0
while True:
    if len(number_to_guess) != 4:
        number_to_guess = input("Please, enter a four-digit number:")
    
    elif number_to_guess == "STOP":
        break
    
    elif cows == 4:
        print("You win")
        break
    
    if len(number_to_guess) == 4:
        while cows < 4 and number_to_compare != "STOP":
            
            if len(number_to_compare) != 4:
                number_to_compare = input("Please, enter a four-digit number or introduce STOP:")
            
            elif len(number_to_compare) == 4:
            
                for x in range(0,4):
                    if number_to_compare[x] == number_to_guess[x]:
                        cows += 1
                    
                    elif:
                        for i in number_to_compare:
                            for y in number_to_guess:
                                if i == y:
                                    bulls += 1
                                else:
                                    bulls = bulls

    print("Cows", str(cow), "and", "Bulls", str(bull))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-cc5aa5405195> in <module>
#      27
#      28                     else:
# ---> 29                         for i in number_to_compare:
#      30                             for y in number_to_guess:
#      31                                 if i == y:
#
# KeyboardInterrupt:

# %%
#Intento 3
number_to_guess = input("Enter a four-digit number or STOP to stop the game")
number_to_compare = input("Enter a four-digit number or STOP to stop the game")
cows = 0
bulls = 0
while True:
    if len(number_to_guess) != 4:
        number_to_guess = input("Please, enter a four-digit number:")
    elif number_to_guess == "STOP":
        break
    elif cows == 4:
        print("You win")
        break
    if len(number_to_guess) == 4:
        while cows < 4 or number_to_compare != "STOP":
            if len(number_to_compare) != 4:
                number_to_compare = input("Please, enter a four-digit number or introduce STOP:")
            elif len(number_to_compare) == 4:
                for x in range(0,4):
                    if number_to_compare[x] == number_to_guess[x]:
                        cows += 1
                    
                    elif number_to_compare[x] in number_to_guess:
                        bulls += 1

    print("Cows", str(cow), "and", "Bulls", str(bull))

# %%
#Intento 4
number_to_guess = input("Enter a four-digit number or STOP to stop the game")
cows = 0
bulls = 0
while True:
    if len(number_to_guess) != 4:
        number_to_guess = input("Please, enter a four-digit number:")
    elif number_to_guess == "STOP":
        break
    elif cows == 4:
        print("You win")
        break
    if len(number_to_guess) == 4:
        while cows < 4 or number_to_compare != "STOP":
            number_to_compare = input("Enter a four-digit number or STOP to stop the game")
            if len(number_to_compare) != 4:
                number_to_compare = input("Please, enter a four-digit number or introduce STOP:")
            elif len(number_to_compare) == 4:
                for x in range(0,4):
                    if x == 3:
                        print("Cows", str(cows), "and", "Bulls", str(bulls))
                    elif number_to_compare[x] == number_to_guess[x]:
                        cows += 1
                    
                    elif number_to_compare[x] in number_to_guess:
                        bulls += 1
