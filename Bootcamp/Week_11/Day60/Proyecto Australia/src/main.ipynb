# %% [markdown]
# # Australia Fires
#
# Enlace a la documentación:
# https://pypi.org/project/PyMySQL/

# %%
# !pip install pymysql
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\maria\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
root_path = os.path.dirname(os.getcwd())
sys.path.append(root_path)
sys.path = list(set(sys.path))

# %%
from src_libs.sql_lib.sql_connector import connection

conn = connection(host="34.229.137.164", port=25001, user="student", password="lebowsky" , database="australia_fires_2")

# %%
import pymysql.cursors
cursor = conn.cursor()

# %%
cursor.execute("SHOW TABLES") 
cursor.fetchall()
# Out:
# [{'Tables_in_australia_fires_2': 'fire_archive_M6_96619'},
#  {'Tables_in_australia_fires_2': 'fire_archive_V1_96617'},
#  {'Tables_in_australia_fires_2': 'fire_nrt_M6_96619'},
#  {'Tables_in_australia_fires_2': 'fire_nrt_V1_96617'},
#  {'Tables_in_australia_fires_2': 'student_findings'}]

# %%
query = """
SELECT *
FROM fire_archive_M6_96619
"""
df1 = pd.read_sql_query(query, conn) 
df1
# Out:
#        index  latitude  longitude  brightness  scan  track    acq_date  \
# 0          0   -11.807   142.0583       313.0   1.0    1.0  2019-08-01
# 1          1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01
# 2          2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01
# 3          3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01
# 4          4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01
# ...      ...       ...        ...         ...   ...    ...         ...
# 36006  36006  -28.0656   131.6334       312.7   1.2    1.1  2019-09-30
# 36007  36007  -28.2625   128.5494       304.9   1.0    1.0  2019-09-30
# 36008  36008  -28.2941   128.5123       301.7   1.0    1.0  2019-09-30
# 36009  36009  -28.3001   128.5530       303.6   1.0    1.0  2019-09-30
# 36010  36010  -30.8641   121.4995       309.1   1.8    1.3  2019-09-30
#
#        acq_time satellite instrument  confidence  version  bright_t31   frp  \
# ...

# %%
query = """
SELECT *
FROM fire_archive_V1_96617
"""
df2 = pd.read_sql_query(query, conn)
df2
# Out:
#          index   latitude  longitude  bright_ti4  scan  track    acq_date  \
# 0            0  -34.45902  150.88040       326.5  0.60   0.71  2019-08-01
# 1            1  -31.70724  151.07191       367.0  0.56   0.69  2019-08-01
# 2            2  -31.39626  149.65253       325.2  0.68   0.74  2019-08-01
# 3            3  -30.39774  152.06432       347.8  0.48   0.65  2019-08-01
# 4            4  -31.20248  151.89766       350.7  0.50   0.66  2019-08-01
# ...        ...        ...        ...         ...   ...    ...         ...
# 184773  184773  -32.37209  116.10032       296.1  0.48   0.40  2019-09-30
# 184774  184774  -32.38958  116.11151       296.1  0.48   0.40  2019-09-30
# 184775  184775  -33.12481  116.03968       299.9  0.47   0.40  2019-09-30
# 184776  184776   -33.6348  122.92641       296.2  0.43   0.38  2019-09-30
# 184777  184777  -33.63897  122.93050       297.3  0.44   0.38  2019-09-30
#
#         acq_time satellite instrument confidence  version  bright_ti5   frp  \
# ...

# %%
query = """
SELECT *
FROM fire_nrt_M6_96619
"""
df3 = pd.read_sql_query(query, conn)
df3
# Out:
#          index latitude  longitude  brightness  scan  track    acq_date  \
# 0            0  -14.281    143.636       323.9   1.7    1.3  2019-10-01
# 1            1  -14.284    143.532       343.5   1.7    1.3  2019-10-01
# 2            2  -14.302    143.706       320.2   1.7    1.3  2019-10-01
# 3            3  -14.283    143.652       320.4   1.7    1.3  2019-10-01
# 4            4  -14.285    143.521       349.4   1.7    1.3  2019-10-01
# ...        ...      ...        ...         ...   ...    ...         ...
# 183588  183588  -32.675    122.113       300.5   2.4    1.5  2020-01-11
# 183589  183589  -16.708    129.646       300.5   1.0    1.0  2020-01-11
# 183590  183590  -16.747    129.653       301.8   1.0    1.0  2020-01-11
# 183591  183591  -32.484    121.319       306.5   1.4    1.2  2020-01-11
# 183592  183592  -30.858    121.500       300.7   1.4    1.2  2020-01-11
#
#         acq_time satellite instrument  confidence version  bright_t31    frp  \
# ...

# %%
query = """
SELECT *
FROM fire_nrt_V1_96617
"""
df4 = pd.read_sql_query(query, conn)
df4
# Out:
#          index   latitude  longitude  bright_ti4  scan  track    acq_date  \
# 0            0  -42.69706  147.70634       333.6  0.57   0.43  2019-10-01
# 1            1  -42.26889  147.31104       336.2  0.39   0.44  2019-10-01
# 2            2  -40.85202  145.38068       327.9  0.46   0.47  2019-10-01
# 3            3  -42.39329  147.47144       346.9  0.38   0.43  2019-10-01
# 4            4  -42.69701  147.70584       334.1  0.56   0.43  2019-10-01
# ...        ...        ...        ...         ...   ...    ...         ...
# 956252  956252  -32.66628  122.15253       306.9  0.39   0.44  2020-01-11
# 956253  956253  -32.58616  123.39582       299.0  0.51   0.41  2020-01-11
# 956254  956254  -33.37853  115.94735       309.7  0.40   0.60  2020-01-11
# 956255  956255  -33.21827  115.75078       300.2  0.49   0.65  2020-01-11
# 956256  956256  -33.22012  115.75043       300.3  0.49   0.65  2020-01-11
#
#         acq_time satellite instrument confidence version  bright_ti5  frp  \
# ...

# %%
query = """
SELECT *
FROM student_findings
"""
pd.read_sql_query(query, conn)
# Out:
# Empty DataFrame
# Columns: [index, chosen_model, acc_score, recall_score]
# Index: []

# %%
df1.isnull().sum()
# Out:
# index         0
# latitude      0
# longitude     0
# brightness    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_t31    0
# frp           0
# daynight      0
# fire_type     0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# index         0
# latitude      0
# longitude     0
# bright_ti4    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_ti5    0
# frp           0
# fire_type     0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# index         0
# latitude      0
# longitude     0
# brightness    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_t31    0
# frp           0
# daynight      0
# dtype: int64

# %%
df4.isnull().sum()
# Out:
# index         0
# latitude      0
# longitude     0
# bright_ti4    0
# scan          0
# track         0
# acq_date      0
# acq_time      0
# satellite     0
# instrument    0
# confidence    0
# version       0
# bright_ti5    0
# frp           0
# daynight      0
# dtype: int64

# %%
df4 = df4.drop(['daynight'], axis = 1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Creating the graph
plt.figure(figsize=(15,10))
correlation_fire1 = df1.corr()
heatmap_fire1 = sns.heatmap(correlation_fire1, cmap="bone",annot=True)
fig_corr_covid = heatmap_fire1.get_figure()

# Labels
plt.yticks(va="center", rotation = 0, fontsize=15)
plt.xticks(fontsize=10)

# Showing the chart
correlation_fire1
# Out:
#                index     longitude    brightness          scan         track  \
# index       1.000000  1.037563e-01  1.581038e-01 -4.500031e-03 -5.544107e-03
# longitude   0.103756  1.000000e+00 -1.040974e-01 -5.184018e-02 -5.476704e-02
# brightness  0.158104 -1.040974e-01  1.000000e+00 -1.059401e-01 -1.085723e-01
# scan       -0.004500 -5.184018e-02 -1.059401e-01  1.000000e+00  9.824843e-01
# track      -0.005544 -5.476704e-02 -1.085723e-01  9.824843e-01  1.000000e+00
# acq_time    0.054372  1.163678e-01 -3.232710e-01 -2.687651e-02 -2.439943e-02
# confidence  0.075489 -3.552895e-02  6.146908e-01 -1.038080e-01 -1.059490e-01
# version     0.000000 -4.866327e-14  5.808995e-14  2.102575e-13  5.918211e-13
# bright_t31  0.097194 -3.804062e-01  6.068445e-01 -9.435634e-02 -9.206383e-02
# frp         0.094743  4.492965e-04  6.611308e-01  2.921166e-01  2.865629e-01
# fire_type  -0.004516  5.580376e-03 -5.416031e-02 -2.412955e-02 -2.446029e-02
#
# ...

# %%
# Creating the graph
plt.figure(figsize=(15,10))
correlation_fire2 = df2.corr()
heatmap_fire2 = sns.heatmap(correlation_fire2, cmap="bone",annot=True)
fig_corr_covid = heatmap_fire2.get_figure()

# Labels
plt.yticks(va="center", rotation = 0, fontsize=15)
plt.xticks(fontsize=10)

# Showing the chart
correlation_fire2
# Out:
#                index  longitude  bright_ti4      scan     track  acq_time  \
# index       1.000000   0.148382    0.055505 -0.021053 -0.014136 -0.022722
# longitude   0.148382   1.000000   -0.139049 -0.013641 -0.035377  0.050549
# bright_ti4  0.055505  -0.139049    1.000000 -0.045501 -0.000385 -0.778073
# scan       -0.021053  -0.013641   -0.045501  1.000000  0.518411  0.017759
# track      -0.014136  -0.035377   -0.000385  0.518411  1.000000 -0.011938
# acq_time   -0.022722   0.050549   -0.778073  0.017759 -0.011938  1.000000
# version          NaN        NaN         NaN       NaN       NaN       NaN
# bright_ti5  0.055110  -0.324462    0.748308 -0.097949 -0.143729 -0.743288
# frp         0.067368  -0.031141    0.410288  0.086054  0.029118 -0.316053
# fire_type   0.012397  -0.014470   -0.040702 -0.006792 -0.009883  0.036951
#
#             version  bright_ti5       frp  fire_type
# index           NaN    0.055110  0.067368   0.012397
# ...

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

import warnings
warnings.filterwarnings('ignore')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36011 entries, 0 to 36010
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   index       36011 non-null  int64
#  1   latitude    36011 non-null  object
#  2   longitude   36011 non-null  float64
#  3   brightness  36011 non-null  float64
#  4   scan        36011 non-null  float64
#  5   track       36011 non-null  float64
#  6   acq_date    36011 non-null  object
#  7   acq_time    36011 non-null  int64
#  8   satellite   36011 non-null  object
#  9   instrument  36011 non-null  object
#  10  confidence  36011 non-null  int64
#  11  version     36011 non-null  float64
#  12  bright_t31  36011 non-null  float64
#  13  frp         36011 non-null  float64
#  14  daynight    36011 non-null  object
#  15  fire_type   36011 non-null  int64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 4.4+ MB

# %%
df1["latitude"] = df1["latitude"].str.replace('%', '').astype(float)
df1
# Out:
#        index  latitude  longitude  brightness  scan  track    acq_date  \
# 0          0  -11.8070   142.0583       313.0   1.0    1.0  2019-08-01
# 1          1  -11.7924   142.0850       319.3   1.0    1.0  2019-08-01
# 2          2  -12.8398   132.8744       311.6   3.1    1.7  2019-08-01
# 3          3  -14.4306   143.3035       310.1   1.1    1.1  2019-08-01
# 4          4  -12.4953   131.4897       310.3   4.0    1.9  2019-08-01
# ...      ...       ...        ...         ...   ...    ...         ...
# 36006  36006  -28.0656   131.6334       312.7   1.2    1.1  2019-09-30
# 36007  36007  -28.2625   128.5494       304.9   1.0    1.0  2019-09-30
# 36008  36008  -28.2941   128.5123       301.7   1.0    1.0  2019-09-30
# 36009  36009  -28.3001   128.5530       303.6   1.0    1.0  2019-09-30
# 36010  36010  -30.8641   121.4995       309.1   1.8    1.3  2019-09-30
#
#        acq_time satellite instrument  confidence  version  bright_t31   frp  \
# ...

# %%
df1['acq_date'] = df1['acq_date'].astype('datetime64[ns]')
df1['month'] = pd.DatetimeIndex(df1["acq_date"]).month

df2['acq_date'] = df2['acq_date'].astype('datetime64[ns]')
df2['month'] = pd.DatetimeIndex(df2["acq_date"]).month

df3['acq_date'] = df3['acq_date'].astype('datetime64[ns]')
df3['month'] = pd.DatetimeIndex(df3["acq_date"]).month

df4['acq_date'] = df4['acq_date'].astype('datetime64[ns]')
df4['month'] = pd.DatetimeIndex(df4["acq_date"]).month

# %% [markdown]
# ## PRIMER PAR DE DATASET M6

# %%
le = preprocessing.LabelEncoder()

# %%
cat_col = ["satellite", "instrument", "daynight" ]
for i in cat_col:
    df1[i] = le.fit_transform(df1[i])

# %%
# no cojo index, acq_date, acq_time y version
X = np.array(df1[["latitude", "longitude", "brightness", "scan", "track", "acq_time", "satellite", "instrument", "confidence", "bright_t31", "frp", "daynight", "month"]])
y = np.array(df1['fire_type'])

# %%
#Divido en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = linear_model.LogisticRegression(n_jobs=-1)

model.fit(X_train, y_train)

score = model.score(X_test,y_test)*100
score
# Out:
# 98.88935165903095

# %%
model.fit(X, y)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
cat_col = ["satellite", "instrument", "daynight" ]
for i in cat_col:
    df3[i] = le.fit_transform(df3[i])

# %%
predictions_submit = model.predict(df3[["latitude", "longitude", "brightness", "scan", "track", "acq_time", "satellite", "instrument", "confidence", "bright_t31", "frp", "daynight", "month"]])
predictions_submit
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df3["fire_type_pred"] = predictions_submit

# %%
df3.to_csv("output/df3_maria.csv", index = False)

# %% [markdown]
# ## SEGUNDO PAR DE DATASET V1

# %%
le = preprocessing.LabelEncoder()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184778 entries, 0 to 184777
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   index       184778 non-null  int64
#  1   latitude    184778 non-null  object
#  2   longitude   184778 non-null  float64
#  3   bright_ti4  184778 non-null  float64
#  4   scan        184778 non-null  float64
#  5   track       184778 non-null  float64
#  6   acq_date    184778 non-null  datetime64[ns]
#  7   acq_time    184778 non-null  int64
#  8   satellite   184778 non-null  object
#  9   instrument  184778 non-null  object
#  10  confidence  184778 non-null  object
#  11  version     184778 non-null  int64
#  12  bright_ti5  184778 non-null  float64
#  13  frp         184778 non-null  float64
#  14  fire_type   184778 non-null  int64
#  15  month       184778 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(4)
# memory usage: 22.6+ MB

# %%
cat_col = ["satellite", "instrument", "confidence"]
for i in cat_col:
    df2[i] = le.fit_transform(df2[i])

# %%
# no cojo index, acq_date, acq_time y version
X = np.array(df2[["latitude", "longitude", "bright_ti4", "scan", "track", "acq_time", "satellite", "instrument", "confidence", "bright_ti5", "frp", "month"]])
y = np.array(df2['fire_type'])

# %%
#Divido en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = linear_model.LogisticRegression(n_jobs=-1)

model.fit(X_train, y_train)

score = model.score(X_test,y_test)*100
score
# Out:
# 97.616083991774

# %%
model.fit(X, y)
# Out:
# LogisticRegression(n_jobs=-1)

# %%
cat_col = ["satellite", "instrument", "confidence"]
for i in cat_col:
    df4[i] = le.fit_transform(df4[i])

# %%
predictions_submit = model.predict(df4[["latitude", "longitude", "bright_ti4", "scan", "track", "acq_time", "satellite", "instrument", "confidence", "bright_ti5", "frp", "month"]])
predictions_submit
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df4["fire_type_pred"] = predictions_submit

# %%
df4.to_csv("output/df4_maria.csv", index = False)
