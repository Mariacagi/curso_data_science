# %% [markdown]
#    #                                                  Titanic Exercise
#    #### Practise Pandas

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# you will have to import at least two other libraries along the exercise

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
filename = "titanic.csv"

# %%
#your code

# %%
titanic = pd.read_csv(filename)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 107.4+ KB

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
# Out:
# (1309, 14)

# %%
titanic.shape
# Out:
# (1309, 14)

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
#your code

# %%
people = pd.DataFrame(titanic.iloc[:, 2:5])
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
#your code

# %%
people3 = people.head(3)
people4 = people.tail(4)
people3.append(people4)
# Out:
#                                 name     sex    age
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
#your code

# %%
s_titanic = titanic.iloc[3:10,:]
s_titanic
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
#your code

# %%
data_frame = titanic.iloc[::-1]
data_frame.index = data_frame.index.astype(str, copy = False)
print(type(data_frame.index))
s_titanic_rev = data_frame.loc["63":"40",:]
s_titanic_rev
# Out:
# <class 'pandas.core.indexes.base.Index'>
#     pclass  survived                                               name  \
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
#your code

# %%
left_columns = titanic.loc[:, "pclass":"parch"]
left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
#your code

# %%
middle_columns = titanic.loc[:, "name":"age"]
middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
#your code

# %%
right_columns = titanic.loc[:, "ticket":"home.dest"]
right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %%
#your code

# %%
data_age = titanic.sort_values(by="age", ascending=False).head()
print(data_age[data_age['survived']==0].head(1)) #The oldest person who died is Mr. Johan Svensson
data_age.loc[data_age["name"].str.contains("Svensson")] # He travelled alone
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1235       3         0  Svensson, Mr. Johan  male  74.0      0      0  347060
#
#        fare cabin embarked boat  body home.dest
# 1235  7.775   NaN        S  NaN   NaN       NaN
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1235       3         0  Svensson, Mr. Johan  male  74.0      0      0  347060
#
#        fare cabin embarked boat  body home.dest
# 1235  7.775   NaN        S  NaN   NaN       NaN

# %%
non_survived = titanic[titanic["survived"]==0]
non_survived.loc[non_survived["age"]==non_survived["age"].max()]
# Out:
#       pclass  survived                 name   sex   age  sibsp  parch  ticket  \
# 1235       3         0  Svensson, Mr. Johan  male  74.0      0      0  347060
#
#        fare cabin embarked boat  body home.dest
# 1235  7.775   NaN        S  NaN   NaN       NaN

# %%
print(f"The oldest person who died in the Titanic incident was {titanic[titanic.age == titanic[titanic.survived == 0].age.max()]['name'].values[0]}")
# Out:
# The oldest person who died in the Titanic incident was Svensson, Mr. Johan

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %%
#your code

# %%
import random

rows = np.random.randint(0,len(titanic)+1, size=5)
rows
# Out:
# array([ 25, 540, 598, 624, 126])

# %%
rows = [random.randint(0,len(titanic)+1) for i in range(5)]
rows
# Out:
# [429, 172, 938, 228, 264]

# %%
import random
rows2 = random.sample(range(0, titanic.shape[0]), 5)
rows2
# Out:
# [1301, 514, 660, 1258, 806]

# %% [markdown]
# This list of numbers are random, could be different.

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
#your code

# %%
titanic_cols = titanic.columns.tolist()
cols = random.sample(titanic_cols, k = 3)
cols
# Out:
# ['sibsp', 'fare', 'embarked']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
#your code

# %%
new_df = pd.DataFrame(titanic,index=rows, columns=cols)
new_df
# Out:
#      sibsp      fare embarked
# 429      0   13.0000        S
# 172      0   26.0000        S
# 938      1    7.8542        S
# 228      1  108.9000        C
# 264      0   35.5000        C

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
titanic = titanic.rename(columns={"sex": "gender"})
a = np.array(titanic["gender"])
array_fe = a == "female"
array_fe = pd.Series(array_fe)
array_fe
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %% [markdown]
# Bonus: Rename the column `"sex"` to `"gender"`

# %%
#your code

# %% [markdown]
# 14. Filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
#your code

# %%
woman_titanic = titanic.loc[titanic["gender"] == "female"]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
woman_titanic = titanic[array_fe]
woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
#your code

# %%
minor_vo = woman_titanic[woman_titanic.age < 18]
minor_vo
# Out:
#       pclass  survived                                       name  gender  \
# 2          1         0               Allison, Miss. Helen Loraine  female
# 55         1         1                  Carter, Miss. Lucile Polk  female
# 92         1         1  Dick, Mrs. Albert Adrian (Vera Gillespie)  female
# 159        1         1               Hippach, Miss. Jean Gertrude  female
# 187        1         1                  Lines, Miss. Mary Conover  female
# ...      ...       ...                                        ...     ...
# 1257       3         1                 Touma, Miss. Maria Youssef  female
# 1265       3         0                  Van Impe, Miss. Catharina  female
# 1279       3         0       Vestrom, Miss. Hulda Amanda Adolfina  female
# 1300       3         1    Yasbeck, Mrs. Antoni (Selini Alexander)  female
# 1304       3         0                       Zabour, Miss. Hileni  female
#
#        age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %%
minor_vo.shape[0]
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
#your code

# %%
dead_wo = woman_titanic[(woman_titanic.age < 18) & (woman_titanic.survived==0)]
dead_wo.shape[0]
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
#your code

# %%
titanic.dropna(how='any').shape
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
#your code

# %%
titanic.dropna(how='all').shape
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
#your code

# %%
titanic.columns[titanic.isnull().sum() > 1000]
# Out:
# Index(['cabin', 'body'], dtype='object')

# %%
titanic.dropna(axis=1, thresh=len(titanic)-1000).shape #Nos quitamos dos columnas, thresh= le tienes que pasar el valor que no es null por tanto la longitud de len menos 1000
# Out:
# (1309, 12)

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
#your code

# %%
percent_missing_boat = titanic["boat"].isnull().sum() * 100 / len(titanic)
#el valor total que nos dice que hay de nulos en la columna boat
percent_missing_boat
# Out:
# 62.87242169595111

# %%
percent_missing_boat.round(2)
# Out:
# 62.87

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` --> `by_class`

# %%
#your code

# %%
groupby_pclass = titanic.groupby('pclass')
by_class_sub = groupby_pclass[['age','fare']]

by_class = by_class_sub.agg(['max','median']) #agg sirve para hacer diferentes operaciones
by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %%
by_classe = titanic.groupby('pclass').agg({"age":["max", "median"], "fare":["max", "median"]})
by_classe
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
#your code

# %%
by_class["age"]["max"]
# Out:
# pclass
# 1    80.0
# 2    70.0
# 3    74.0
# Name: max, dtype: float64

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
#your code

# %%
by_class["fare"]["median"]
# Out:
# pclass
# 1    60.0000
# 2    15.0458
# 3     8.0500
# Name: median, dtype: float64

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
#your code

# %%
counted = pd.pivot_table(titanic, values='survived', index=["pclass"], columns=['gender'], aggfunc=np.sum)
counted
#Tenemos que agrupar por columnas y poner un indice
#A partir de este data frame para los valores survived utilizando los valores de genero como columnas y como indice vas a utilizar los valores de pclass y todo esa agrupación la tienes que hacer sumando
# Out:
# gender  female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
#your code

# %%
counted["total"] = counted['female'] + counted['male']
counted["total"]
# Out:
# pclass
# 1    200
# 2    119
# 3    181
# Name: total, dtype: int64

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the more?

# %%
#your code

# %%
counted.sort_values(by="total", ascending=False).head(1)
# Out:
# gender  female  male  total
# pclass
# 1          139    61    200

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
#your code

# %%
women_conds = titanic[(titanic.gender == "female") &
                      (titanic.survived==1) & 
                      (titanic.pclass==3) & 
                      (titanic.age<30)]
women_conds.shape[0]
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
#your code

# %%
men_conds = titanic.loc[(titanic.gender == "male") & 
                        (titanic.survived==0) & 
                        (titanic.pclass==1) & 
                        (titanic.age>50)]
men_conds.shape[0]
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
#your code

# %%
array_name = titanic["name"].nunique
array_name
# Out:
# <bound method IndexOpsMixin.nunique of 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object>

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
#your code

# %%
titanic[titanic["name"].duplicated()]["name"]
# Out:
# 726    Connolly, Miss. Kate
# 925        Kelly, Mr. James
# Name: name, dtype: object

# %%
#Otra forma de hacerlo
titanic.name.value_counts()
# Out:
# Connolly, Miss. Kate              2
# Kelly, Mr. James                  2
# Funk, Miss. Annie Clemmer         1
# Dean, Master. Bertram Vere        1
# Toufik, Mr. Nakli                 1
#                                  ..
# Taussig, Mr. Emil                 1
# Nysten, Miss. Anna Sofia          1
# Stranden, Mr. Juho                1
# Baclini, Miss. Marie Catherine    1
# Mamee, Mr. Hanna                  1
# Name: name, Length: 1307, dtype: int64

# %%
list(titanic.name.value_counts()[titanic.name.value_counts()>1].index)
# Out:
# ['Connolly, Miss. Kate', 'Kelly, Mr. James']

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
#your code

# %%
plt.hist(titanic.age, bins=10) #Hist representa un gráfico con la frecuencia de valores
#hist devuelve una gráfica
plt.grid(True)
plt.show()

# %%
x = plt.hist(titanic.age) #Para ver cual es la frecuencia exacta de cada uno de ellos
x
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.17 ,  8.153, 16.136, 24.119, 32.102, 40.085, 48.068, 56.051,
#         64.034, 72.017, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
#your code

# %%
#Intento 1
female = titanic.loc[titanic.gender == "female"].count()
male = titanic.loc[titanic.gender == "male"].count()

# %%
plt.hist([female, male])
# Out:
# (array([[1., 1., 0., 2., 1., 9., 0., 0., 0., 0.],
#         [0., 3., 0., 0., 0., 1., 0., 1., 0., 9.]]),
#  array([  8. ,  91.5, 175. , 258.5, 342. , 425.5, 509. , 592.5, 676. ,
#         759.5, 843. ]),
#  <a list of 2 BarContainer objects>)

# %% [markdown]
# #Intento 2
# ## Opción 1 ##

# %%
#Intento 2
gender_chart = plt.hist(titanic.gender, bins=3)

plt.show()

# %% [markdown]
# ## Opción 2 ##

# %%
titanic.gender.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Opción 3 ##

# %%
titanic.gender.value_counts().values
# Out:
# array([843, 466], dtype=int64)

# %%
plt.bar(x=["male", "female"], height=[843,466])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# ## Opción 4 ##

# %%
plt.bar(x=titanic.gender.value_counts().index.values, height=titanic.gender.value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
#your code

# %%
#Intento 1
plt.plot(titanic.gender).countplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-5e8842111216> in <module>
#       1 #Intento 1
# ----> 2 plt.plot(titanic.gender).countplot()
#
# AttributeError: 'list' object has no attribute 'countplot'

# %% [markdown]
# #Intento 2
# ## Opción 1 ##

# %%
#Intento 2
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="sex", data=titanic)

# %% [markdown]
# ## Opción 2 ##

# %%
graphs = sns.countplot(titanic["sex"])

# %% [markdown]
# ## Opción 3 ##

# %%
sns.countplot(x="gender", data=titanic)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](catplotgen.png)

# %%
#Intento 1
sns.catplot(x="sex", col="survived", data=titanic, kind="count")

# %% [markdown]
# #Intento 2
#
# ## Opción 1 ##

# %%
#Intento 2
yes_survived = titanic[(titanic['survived'] == 1)]
sns.catplot(x="gender", col='survived', data=yes_survived, kind="count")
#Catplot muestra el valor total de hombres y mujeres murieron con respecto a los que perdieron la vida de hombres
#La relación de las mujeres que sobrevivieron respecto al total y la relación de los hombres que sobreviverion respecto al total

# %% [markdown]
# ## Opción 2 ##

# %%
graph_survived = sns.catplot(x=titanic["gender"], y=titanic["survived"], data=titanic, kind="bar")
graph_survived

# %% [markdown]
# ## Opción 3 ##

# %%
graph_survived2 = sns.catplot(x="gender", y="survived", data=titanic, kind="bar")
graph_survived2

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](kdeplotsur.png)

# %%
#Intento 1
sns.kdeplot(data=titanic, x="age", hue="survived", label="Not Survived", shade = True, common_norm=False, color="red", alpha=.5, linewidth=0,)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
#Intento 2
not_survived = titanic[(titanic['survived'] == 0)]["age"]
not_survived
# Out:
# 2        2.0
# 3       30.0
# 4       25.0
# 7       39.0
# 9       71.0
#         ...
# 1304    14.5
# 1305     NaN
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, Length: 809, dtype: float64

# %%
sns.kdeplot(data=not_survived, label="Not Survived", shade=True, color="red")
plt.legend()

# %% [markdown]
# ## Opción 2 ##

# %%
sns.kdeplot(titanic.age[titanic.survived == 0], color="red", label= "Not Survived", shade= True)
sns.kdeplot(titanic.age[titanic.survived == 1], color = "green", label= "Survived", shade = True)
plt.legend()
