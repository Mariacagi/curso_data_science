# %% [markdown]
# # Visualizing Chipotle's Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the 
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
    
chipo = pd.read_csv(url, sep = '\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 5. Create a histogram of the top 5 items bought

# %%
groupby_item_name = chipo.groupby("item_name").count()
sort_quantity = groupby_item_name.sort_values(by="quantity").tail()
sort_quantity
# Out:
#                      order_id  quantity  choice_description  item_price
# item_name
# Canned Soft Drink         301       301                 301         301
# Steak Burrito             368       368                 368         368
# Chips and Guacamole       479       479                   0         479
# Chicken Burrito           553       553                 553         553
# Chicken Bowl              726       726                 726         726

# %%
plt.bar(x=sort_quantity.index.values, height=sort_quantity.quantity)

plt.xticks(rotation='vertical')
plt.xlabel("Items")
plt.ylabel("Number of Times Ordered")

plt.title("Most Ordered Chipotle's Items")

plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the number of items orderered per order price
# #### Hint: Price should be in the X-axis and Items ordered in the Y-axis

# %%
# Out:
# (0, 36.7178857951459)

# %%
chipo['item_price'] = chipo['item_price'].str.replace(r'\$', '').astype(float)
orders = chipo.groupby('order_id').sum()

plt.scatter(x = orders.item_price, y = orders.quantity, s = 50, c = 'green')

plt.title('Number of items ordered per order price')
plt.xlabel('Order Price')
plt.ylabel('Items ordered')

plt.show()

# %% [markdown]
# ### BONUS: Create a question and a graph to answer your own question.
